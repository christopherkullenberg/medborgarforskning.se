# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
def PQquery(P, Q):
    sparql.setQuery("""
    SELECT ?item ?itemLabel

    WHERE {
      # ?item wdt:""" + P + """ wd:""" + Q + """.
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
    """)

    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results

# %% [markdown]
# # Properties and Qs
#
#
# | Property | Meaning   | Q | Meaning |
# |------|------|------|------|
# |   P50 | author | Q16633168 | Christopher Kullenberg |
# | P108 |  employer |Q371522 | University of gothenburg |
# |  P31 | instance of  | Q24577212 |  citizen science|
# | P2860 | cites work | Q30386191 | "What is citizen science..." |
# | P921 | main subject | Q13442814 | scholarly article |

# %%
results = PQquery("P31", "Q24577212")

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
print(len(results_df))
results_df
# Out:
# 77
#    item.type                                item.value itemLabel.xml:lang  \
# 0        uri    http://www.wikidata.org/entity/Q210748                 en
# 1        uri    http://www.wikidata.org/entity/Q581771                 en
# 2        uri    http://www.wikidata.org/entity/Q585511                 en
# 3        uri    http://www.wikidata.org/entity/Q836563                 en
# 4        uri    http://www.wikidata.org/entity/Q905745                 en
# ..       ...                                       ...                ...
# 72       uri  http://www.wikidata.org/entity/Q65581809                 en
# 73       uri  http://www.wikidata.org/entity/Q66355439                 en
# 74       uri  http://www.wikidata.org/entity/Q71633630                 en
# 75       uri  http://www.wikidata.org/entity/Q73872616                 en
# 76       uri  http://www.wikidata.org/entity/Q74025745                 en
#
#    itemLabel.type                   itemLabel.value
# ...
